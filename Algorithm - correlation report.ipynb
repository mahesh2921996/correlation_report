# %% [markdown]
# ## Algorithm: Correlation Report
#
#                                          Name:- Mahesh Deshmukh
#                                          Contact:- mb29deshmukh@gmail.com
#                                          Name of Institute:- The CareerGram Institute, Pune.

# %% [markdown]
# ### Objective

# %% [markdown]
#     In data science, correlation is an important concept to understand the relationship between numerical variables. With   the help of correlation, we can easily tell how much two numerical variables are accociated with each other. Generally, correlation can be classified into strong, modrate, weak etc. We get the correlation matrix with the help of the corr() function in Pandas DataFrame, but we can not easily get pairs of different types of correlation, eg. Pairs of strong    correlation variables. So, that purpose, we can make the algorithm, which are returns the different type of correlation   pairs.

# %% [markdown]
# ### The Task

# %% [markdown]
#     Therefore by defining our objective, we need to do the following task: 1) Separating numerical variable pairs for          different type of correlations from correlation matrix.

# %% [markdown]
# ### Abstract

# %% [markdown]
#         Sometimes, we need to know which variables have strong correlation or weak correlation for analysis purpose.         Therefore, we have to find out strong or weak correlated variables from seeing correlation matrix. If more numerical    variables present in dataset, then took more time to seperate out variables for different type of correlations. And a   few of pairs miss out. That purporse, we make a algorithm, which gives the list (i.e. dataframe) of correlation pairs.
#         We know that the correlation always lies between -1 and +1. Suppose, the correlation is lie between +/- 0.95 to +/- 1, then we can say these variables have very strong correlation. The values in +/- 0.70 to +/- 0.95, have strong         correlations. For moderate correlation, the value will be +/- 50 to +/- 70. And for weak correlation, the value will be +/- 0.25 to +/- 50. The very weak correlation variable always lies in +0.25 to -0.25. If no any association between     variables, then correlation is 0. So, this algorithm follows these rules or conditions. We can also find correlation    pairs between specific ranges.

# %% [markdown]
# ### Introduction

# %% [markdown]
#         Correlation is a very important factor in Data Analysis. It helps to tell which numerical variable is more          associated with another numerical variable. Association means statistical relationship. Generally, we can tell which    variables are linearally associated with the help of correlation. The correlation is always between -1 and +1. Roughly  speaking, if correlation (r) is around 0.95, then we can say that these variables have a strong association. Those with r around +/- 5 to +/- 0.75 display moderate association, and those with r around +/- 0.25 have a weak association.
#         Users can find strongly, moderately or weakly correlated variables with the help of this algorithm. The algorithm   returns following reports: i) Very Strong Correlation, ii) Strong Correlation, iii) Moderate Correlation, iv) Weak             Correlation, v) Very Weak Correlation, vi) No Correlation, and vii) Customize Correlation.

# %% [markdown]
# ### The Architecture

# %% [markdown]
# ![Architecture_Correlation_Report.jpg](attachment:Architecture_Correlation_Report.jpg)

# %% [markdown]
# ### Data Exploration

# %% [markdown]
#     Data Exploration is the method to see the data with the help of statistics and visualization tools. In that step, we can handle missing values and duplicate values. Also, we can do feature engineering.

# %%
# Importing necessary libraries.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reading a dataset.
df = pd.read_csv(r"C:\Users\91950\OneDrive\Desktop\CareerGram-ML & AI\Book - Notes\CarPrice_Assignment.csv")

# %%
# Showing the first five rows.
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
# Showing the dimension of dataset.
df.shape
# Out:
# (205, 26)

# %% [markdown]
# There are 205 rows and 26 columns present.

# %%
# Finding the null values from that dataset.
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# In that dataset, no null value is present.

# %%
# Finding the duplicate value from this dataset.
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate value present.

# %% [markdown]
# ### Correlation

# %% [markdown]
#     Correlation (r) is a standardized measure of linear association between two numerical variables. To find the correlatio-n, divide the covariance by the product of the standard deviations.
#
#             corr(x, y) = cov(x, y) / S_x * S_y
#
#     The correlation, does not have units and can be shown always to lie between -1 and +1,
#
#              -1 <= corr(x, y) <= +1

# %%
# Correlation matrix
data = df.corr()
data
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %% [markdown]
#     A correlation matrix is a table showing correlation coefficients between variables.

# %%
# Seeing the correlation matrix with the help of a Heatmap.
plt.figure(figsize=(14,8))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# From above graph, we can say that highwaympg and citympg variable have very strong corrrelation (i.e. 0.97).

# %% [markdown]
# ### Correlation Report

# %% [markdown]
#        If you see the correlation matrix, then you notice that you take more time to find out a strong correlation variables or weak correlation variables. With the help of a heatmap, we can reduce time to search, but difficult to findout all   variables for perticular correlation. Therefore, we make the correlation report algorithm to reduce these efforts.

# %%
class correlation_report:
    """This algorithm helps to find very strong correlation variables, strong correlation variables, 
    moderate correlation variables, weak correlation variables, very weak correlation variables, and 
    defined ranges correlation variables."""
    def __init__(self,dataframe):
        self.corr_df = dataframe.corr()

    def _vsc(self,r):
        """This is a condition for find very strong correlation pairs."""
        vsc = ((1>=r) & (r>=0.95)) | ((-0.95>=r) & (r>=-1))
        return vsc
    
    def _sc(self,r):
        """This is a condition for find strong correlation pairs."""
        sc = ((0.95>r) & (r>=0.70)) | ((-0.70>=r) & (r>-0.95))
        return sc
    
    def _mc(self,r):
        """This is a condition for find moderate correlation pairs."""
        mc = ((0.70>r) & (r>=0.50)) | ((-0.50>=r) & (r>-0.70))
        return mc
    
    def _wc(self,r):
        """This is a condition for find weak correlation pairs."""
        wc = ((0.50>r) & (r>=0.25)) | ((-0.25>=r) & (r>-0.50))
        return wc
    
    def _vwc(self,r):
        """This is a condition for find very weak correlation pairs."""
        vwc = ((0.25>r) & (r>-0.25) & (r!=0))
        return vwc
    
    def _nc(self,r):
        """This is a condition for find no correlation pairs."""
        nc = (r==0)
        return nc
        
    def __remove_null(self, reducied_df):
        """This method helps to return the appropriate data frame."""
        col_ls = []
        index_ls = []
        value = []
        for col in reducied_df.columns:
            for null,index in zip(reducied_df[col].isnull(), reducied_df.index):
                if null==False:
                    col_ls.append(col)
                    index_ls.append(index)
                    value.append(reducied_df.loc[col,index])
        ans_df = pd.DataFrame(dict(First_Variable=col_ls, Second_Variable=index_ls, correlation_value=value))
        ans_df['bool_corr'] = ans_df['correlation_value'].duplicated()
        ans_df = ans_df.where(ans_df['bool_corr']==False)
        ans_df.dropna(inplace=True)
        ans_df.reset_index(drop=True, inplace=True)
        ans_df.drop(labels="bool_corr", axis=1, inplace=True)
        return ans_df
        
    def very_strong_corr(self):
        """This method helps to find the very strong correlation pairs.
           Returns
           -------
           Correlation Pairs : Data Frame
                It returns the correlation pairs between -/+ 1 to -/+ 0.95 correlation values.
        """
        result = self.corr_df[self._vsc(self.corr_df)]
        return self.__remove_null(result)
    
    def strong_corr(self):
        """This method helps to find the strong correlation pairs.
           Returns
           -------
           Correlation Pairs : Data Frame
                It returns the correlation pairs between -/+ 0.95 to -/+ 0.70 correlation values.
        """
        result = self.corr_df[self._sc(self.corr_df)]
        return self.__remove_null(result)
    
    def moderate_corr(self):
        """This method helps to find the moderate correlation pairs.
           Returns
           -------
           Correlation Pairs : Data Frame
                It returns the correlation pairs between -/+ 0.70 to -/+ 0.50 correlation values.
        """
        result = self.corr_df[self._mc(self.corr_df)]
        return self.__remove_null(result)
    
    def weak_corr(self):
        """This method helps to find the weak correlation pairs.
           Returns
           -------
           Correlation Pairs : Data Frame
                It returns the correlation pairs between -/+ 0.50 to -/+ 0.25 correlation values.
        """
        result = self.corr_df[self._wc(self.corr_df)]
        return self.__remove_null(result)
    
    def very_weak_corr(self):
        """This method helps to find the very weak correlation pairs.
           Returns
           -------
           Correlation Pairs : Data Frame
                It returns the correlation pairs between -0.25 to 0.25 correlation values.
        """
        result = self.corr_df[self._vwc(self.corr_df)]
        return self.__remove_null(result)
    
    def no_corr(self):
        """This method helps to find the no correlation pairs.
           Returns
           -------
           Correlation Pairs : Data Frame
                It returns the no correlation pairs.
        """
        result = self.corr_df[self._nc(self.corr_df)]
        return self.__remove_null(result)
    
    def customize_corr(self, lower_range=-1, upper_range=1):
        """This method helps to find the correlation pairs in the defined range.
            Parameters
            ----------
            lower_range : float_value
                          The lower correlation value, which gets the correlation pairs above that value.
                          The default, lower_range is -1.
            upper_range : float_value
                          The upper correlation value, which gets the correlation pairs below that value.
                          The default, upper_range is +1.
                          
            Returns
            -------
            Correlation Pairs : Data Frame
                 It returns the correlation pairs between given lower and upper correlation values. 
                 
            Notes
            -----
            The lower range is always smaller than the upper range, and these range should be between -1 to 1.
            
        """
        if -1<=lower_range<upper_range<=1:
            result = self.corr_df[(upper_range>=self.corr_df) & (self.corr_df>=lower_range)]
            return self.__remove_null(result)
        else:
            print("The lower range is always smaller than the upper range, and these range should be between -1 to 1.")

# %%
# Declaring the object.
obj = correlation_report(df)

# %%
# Returning the very strong correlated variables.
obj.very_strong_corr()
# Out:
#   First_Variable Second_Variable  correlation_value
# 0         car_ID          car_ID           1.000000
# 1        citympg      highwaympg           0.971337

# %%
# Returning the strong correlated variables.
obj.strong_corr()
# Out:
#    First_Variable Second_Variable  correlation_value
# 0       wheelbase       carlength           0.874587
# 1       wheelbase        carwidth           0.795144
# 2       wheelbase      curbweight           0.776386
# 3       carlength        carwidth           0.841118
# 4       carlength      curbweight           0.877728
# 5       carlength      highwaympg          -0.704662
# 6        carwidth      curbweight           0.867032
# 7        carwidth      enginesize           0.735433
# 8        carwidth           price           0.759325
# 9      curbweight      enginesize           0.850594
# 10     curbweight      horsepower           0.750739
# 11     curbweight         citympg          -0.757414
# 12     curbweight      highwaympg          -0.797465
# 13     curbweight           price           0.835305
# 14     enginesize      horsepower           0.809769
# 15     enginesize           price           0.874145
# 16     horsepower         citympg          -0.801456
# ...

# %%
# Returning the modreate correlated variables.
obj.moderate_corr()
# Out:
#    First_Variable Second_Variable  correlation_value
# 0       symboling       wheelbase          -0.531954
# 1       symboling       carheight          -0.541038
# 2       wheelbase       carheight           0.589435
# 3       wheelbase      enginesize           0.569329
# 4       wheelbase      highwaympg          -0.544082
# 5       wheelbase           price           0.577816
# 6       carlength      enginesize           0.683360
# 7       carlength       boreratio           0.606454
# 8       carlength      horsepower           0.552623
# 9       carlength         citympg          -0.670909
# 10      carlength           price           0.682920
# 11       carwidth       boreratio           0.559150
# 12       carwidth      horsepower           0.640732
# 13       carwidth         citympg          -0.642704
# 14       carwidth      highwaympg          -0.677218
# 15     curbweight       boreratio           0.648480
# 16     enginesize       boreratio           0.583774
# ...

# %%
# Returning the weak correlated variables.
obj.weak_corr()
# Out:
#       First_Variable   Second_Variable  correlation_value
# 0             car_ID         carheight           0.255960
# 1             car_ID         boreratio           0.260064
# 2          symboling         carlength          -0.357612
# 3          symboling           peakrpm           0.273606
# 4          wheelbase         boreratio           0.488750
# 5          wheelbase        horsepower           0.353294
# 6          wheelbase           peakrpm          -0.360469
# 7          wheelbase           citympg          -0.470414
# 8          carlength         carheight           0.491029
# 9          carlength           peakrpm          -0.287242
# 10          carwidth         carheight           0.279210
# 11         carheight        curbweight           0.295572
# 12         carheight  compressionratio           0.261214
# 13         carheight           peakrpm          -0.320411
# 14        curbweight           peakrpm          -0.266243
# ...

# %%
# Returning the very weak correlated variables.
obj.very_weak_corr()
# Out:
#       First_Variable   Second_Variable  correlation_value
# 0             car_ID         symboling          -0.151621
# 1             car_ID         wheelbase           0.129729
# 2             car_ID         carlength           0.170636
# 3             car_ID          carwidth           0.052387
# 4             car_ID        curbweight           0.071962
# 5             car_ID        enginesize          -0.033930
# 6             car_ID            stroke          -0.160824
# 7             car_ID  compressionratio           0.150276
# 8             car_ID        horsepower          -0.015006
# 9             car_ID           peakrpm          -0.203789
# 10            car_ID           citympg           0.015940
# 11            car_ID        highwaympg           0.011255
# 12            car_ID             price          -0.109093
# 13         symboling          carwidth          -0.232919
# 14         symboling        curbweight          -0.227691
# ...

# %%
# Returning the no correlated variables.
obj.no_corr()
# Out:
# Empty DataFrame
# Columns: [First_Variable, Second_Variable, correlation_value]
# Index: []

# %%
# Returning the correlated variables in a specific ranges.
obj.customize_corr(-0.20, 0)
# Out:
#    First_Variable   Second_Variable  correlation_value
# 0          car_ID         symboling          -0.151621
# 1          car_ID        enginesize          -0.033930
# 2          car_ID            stroke          -0.160824
# 3          car_ID        horsepower          -0.015006
# 4          car_ID             price          -0.109093
# 5       symboling        enginesize          -0.105790
# 6       symboling         boreratio          -0.130051
# 7       symboling            stroke          -0.008735
# 8       symboling  compressionratio          -0.178515
# 9       symboling           citympg          -0.035823
# 10      symboling             price          -0.079978
# 11      carheight            stroke          -0.055307
# 12      carheight        horsepower          -0.108802
# 13      carheight           citympg          -0.048640
# 14      carheight        highwaympg          -0.107358
# 15      boreratio            stroke          -0.055909
# ...

# %% [markdown]
# ### Conclusion

# %% [markdown]
# 1. We find the different correlation pairs successfully.
# 2. We save time by searching those pairs from correlation matrix.
# 3. We can find the correlation pairs between the specific lower and upper range successfully.

# %% [markdown]
# ### Future Work and Scope

# %% [markdown]
# The next version of this algorithm is to add a scatterplot to that algorithm. So, user can see acutal relation between that variables. Also, we add one more report to find the association between categorical variables.

# %% [markdown]
# ### Acknowledgements

# %% [markdown]
#
# First and foremost, I am grateful of my project guide Dhairyashil Jagadale (sir) wholeheartedly for his valuable guidance. I am also thankful of the CareerGram Institute, Pune, where I got the golden opportunity to work on this project. And finally, I thank to my parents and friends for their contiunous suport.

# %% [markdown]
# ### References

# %% [markdown]
# 1. Robert Stine, and Dean Foster (2014). Statistics for Business Decision Making and Analysis, Pearson Education Limited, England.
# 2. Pandas corr() function documentations at https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html
# 3. heatmap() in Seaborn documentations at https://seaborn.pydata.org/generated/seaborn.heatmap.html
# 4. Pandas Library: https://pandas.pydata.org/
# 5. Seaborn Library: https://seaborn.pydata.org/
